# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Dense
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import Huber
from keras.optimizers import SGD
from google.colab import drive

# %%
drive.mount('/content/drive',force_remount=True)
# %cd "/content/drive/My Drive/ml-home-work"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/ml-home-work

# %%
df = pd.read_csv('tesla.csv')

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close   Volume
# Date
# 2018-01-02  312.000000  322.109985  311.000000  320.529999  320.529999  4352200
# 2018-01-03  321.000000  325.250000  315.549988  317.250000  317.250000  4521500
# 2018-01-04  312.869995  318.549988  305.679993  314.619995  314.619995  9946300
# 2018-01-05  316.619995  317.239990  312.000000  316.579987  316.579987  4591200
# 2018-01-08  316.000000  337.019989  315.500000  336.410004  336.410004  9859400

# %%
df['Adj Close'].plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %%
window_size = 32 # Allow us to look at 32 days into the past
# Prepare the data so that we have 32 day windows and predict what the next day should be

# Get indices of access for the data
num_samples = len(df) - window_size
indices = np.arange(num_samples).astype(np.int)[:,None] + np.arange(window_size + 1).astype(np.int)

# %%
data = df['Adj Close'].values[indices]

# %%
X = data[:,:-1] # Each row represents 32 days in the past
y = data[:,-1] # Each output value represents the 33rd day

# %%
# Train and test split
split_fraction = 0.8
ind_split = int(split_fraction * num_samples)
X_train = X[:ind_split]
y_train = y[:ind_split]
X_test = X[ind_split:]
y_test = y[ind_split:]

# %% [markdown]
# Method #1 - Ridge Regression

# %%
# Train
ridge_model = Ridge()
ridge_model.fit(X_train, y_train)

# Infer
y_pred_train_ridge = ridge_model.predict(X_train)
y_pred_ridge = ridge_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_ridge['Adj Close Train'] = y_pred_train_ridge[:-window_size]
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %%
# Same for the test
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_ridge['Adj Close Test'] = y_pred_ridge
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# # Method #2 - Gradient Boosting Trees

# %%
# Model #2 - Gradient Boosting Trees
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)

# Infer
y_pred_train_gb = gb_model.predict(X_train)
y_pred_gb = gb_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_gb['Adj Close Train'] = y_pred_train_gb[:-window_size]
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %%
# Same for the test
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_gb['Adj Close Test'] = y_pred_gb
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Method #3 - Using neural networks with 1D convolutional and LSTM layers

# %%
# Model #3 - Using RNNs
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])

keras_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 32, 128)           768
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 128)           82048
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32, 128)           131584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 358,465
# Trainable params: 358,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# neural networks learn better when the data is normalized so we will normalize the data to the  [−1,1]  range by using Scikit-learn's MinMaxScaler. Therefore, we need to find apply this scaling on all of the price data, then decompose it into the training and test sets again.

# %%
# First figure out the right learning rate
lr_schedule = LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = SGD(lr=1e-8, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
# Scale the data due to LSTM units
scaler = MinMaxScaler(feature_range=(-1, 1))
data_transform = scaler.fit_transform(df['Adj Close'].values[:,None])
data_transform = data_transform[indices]
X2 = data_transform[:,:-1]
y2 = data_transform[:,-1]
X_train_reshape = X2[:ind_split]
y_train_reshape = y2[:ind_split]
X_test_reshape = X2[ind_split:]
y_test_reshape = y2[ind_split:]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, callbacks=[lr_schedule], validation_data=(X_test_reshape, y_test_reshape))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 316 samples, validate on 80 samples
# Epoch 1/250
# 316/316 [==============================] - 3s 9ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 2/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 3/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 4/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 5/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 6/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 7/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 8/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 9/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 10/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 11/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 12/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 13/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 14/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 15/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 16/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 17/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 18/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 19/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 20/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 21/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 22/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 23/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 24/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 25/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 26/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 27/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 28/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5531
# Epoch 29/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5532
# Epoch 30/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5532
# Epoch 31/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5532
# Epoch 32/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3471 - val_loss: 0.1694 - val_mean_absolute_error: 0.5532
# Epoch 33/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5532
# Epoch 34/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5532
# Epoch 35/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0899 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5532
# Epoch 36/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0899 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5532
# Epoch 37/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5532
# Epoch 38/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5532
# Epoch 39/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5533
# Epoch 40/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5533
# Epoch 41/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3470 - val_loss: 0.1695 - val_mean_absolute_error: 0.5533
# Epoch 42/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3469 - val_loss: 0.1695 - val_mean_absolute_error: 0.5533
# Epoch 43/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3469 - val_loss: 0.1695 - val_mean_absolute_error: 0.5533
# Epoch 44/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3469 - val_loss: 0.1696 - val_mean_absolute_error: 0.5534
# Epoch 45/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3469 - val_loss: 0.1696 - val_mean_absolute_error: 0.5534
# Epoch 46/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3468 - val_loss: 0.1696 - val_mean_absolute_error: 0.5534
# Epoch 47/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0898 - mean_absolute_error: 0.3468 - val_loss: 0.1696 - val_mean_absolute_error: 0.5535
# Epoch 48/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0897 - mean_absolute_error: 0.3468 - val_loss: 0.1696 - val_mean_absolute_error: 0.5535
# Epoch 49/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0897 - mean_absolute_error: 0.3467 - val_loss: 0.1697 - val_mean_absolute_error: 0.5536
# Epoch 50/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0897 - mean_absolute_error: 0.3467 - val_loss: 0.1697 - val_mean_absolute_error: 0.5536
# Epoch 51/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0897 - mean_absolute_error: 0.3466 - val_loss: 0.1697 - val_mean_absolute_error: 0.5537
# Epoch 52/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0896 - mean_absolute_error: 0.3466 - val_loss: 0.1698 - val_mean_absolute_error: 0.5538
# Epoch 53/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0896 - mean_absolute_error: 0.3465 - val_loss: 0.1698 - val_mean_absolute_error: 0.5538
# Epoch 54/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0896 - mean_absolute_error: 0.3464 - val_loss: 0.1699 - val_mean_absolute_error: 0.5539
# Epoch 55/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0895 - mean_absolute_error: 0.3463 - val_loss: 0.1699 - val_mean_absolute_error: 0.5540
# Epoch 56/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0895 - mean_absolute_error: 0.3462 - val_loss: 0.1700 - val_mean_absolute_error: 0.5541
# Epoch 57/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0894 - mean_absolute_error: 0.3461 - val_loss: 0.1701 - val_mean_absolute_error: 0.5543
# Epoch 58/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0894 - mean_absolute_error: 0.3460 - val_loss: 0.1701 - val_mean_absolute_error: 0.5544
# Epoch 59/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0893 - mean_absolute_error: 0.3459 - val_loss: 0.1702 - val_mean_absolute_error: 0.5546
# Epoch 60/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0893 - mean_absolute_error: 0.3457 - val_loss: 0.1703 - val_mean_absolute_error: 0.5548
# Epoch 61/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0892 - mean_absolute_error: 0.3456 - val_loss: 0.1704 - val_mean_absolute_error: 0.5550
# Epoch 62/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0891 - mean_absolute_error: 0.3454 - val_loss: 0.1706 - val_mean_absolute_error: 0.5552
# Epoch 63/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0890 - mean_absolute_error: 0.3452 - val_loss: 0.1707 - val_mean_absolute_error: 0.5555
# Epoch 64/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0889 - mean_absolute_error: 0.3449 - val_loss: 0.1709 - val_mean_absolute_error: 0.5557
# Epoch 65/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0888 - mean_absolute_error: 0.3447 - val_loss: 0.1710 - val_mean_absolute_error: 0.5560
# Epoch 66/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0886 - mean_absolute_error: 0.3444 - val_loss: 0.1712 - val_mean_absolute_error: 0.5564
# Epoch 67/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0885 - mean_absolute_error: 0.3440 - val_loss: 0.1714 - val_mean_absolute_error: 0.5568
# Epoch 68/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0883 - mean_absolute_error: 0.3437 - val_loss: 0.1717 - val_mean_absolute_error: 0.5572
# Epoch 69/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0881 - mean_absolute_error: 0.3433 - val_loss: 0.1719 - val_mean_absolute_error: 0.5577
# Epoch 70/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0879 - mean_absolute_error: 0.3428 - val_loss: 0.1723 - val_mean_absolute_error: 0.5583
# Epoch 71/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0877 - mean_absolute_error: 0.3423 - val_loss: 0.1726 - val_mean_absolute_error: 0.5589
# Epoch 72/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0875 - mean_absolute_error: 0.3418 - val_loss: 0.1730 - val_mean_absolute_error: 0.5596
# Epoch 73/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0872 - mean_absolute_error: 0.3412 - val_loss: 0.1734 - val_mean_absolute_error: 0.5603
# Epoch 74/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0869 - mean_absolute_error: 0.3405 - val_loss: 0.1738 - val_mean_absolute_error: 0.5611
# Epoch 75/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0865 - mean_absolute_error: 0.3397 - val_loss: 0.1744 - val_mean_absolute_error: 0.5620
# Epoch 76/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0861 - mean_absolute_error: 0.3389 - val_loss: 0.1749 - val_mean_absolute_error: 0.5631
# Epoch 77/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0857 - mean_absolute_error: 0.3379 - val_loss: 0.1756 - val_mean_absolute_error: 0.5643
# Epoch 78/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0852 - mean_absolute_error: 0.3369 - val_loss: 0.1764 - val_mean_absolute_error: 0.5656
# Epoch 79/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0847 - mean_absolute_error: 0.3357 - val_loss: 0.1772 - val_mean_absolute_error: 0.5671
# Epoch 80/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0841 - mean_absolute_error: 0.3344 - val_loss: 0.1782 - val_mean_absolute_error: 0.5688
# Epoch 81/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0834 - mean_absolute_error: 0.3329 - val_loss: 0.1792 - val_mean_absolute_error: 0.5707
# Epoch 82/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0827 - mean_absolute_error: 0.3313 - val_loss: 0.1804 - val_mean_absolute_error: 0.5727
# Epoch 83/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0819 - mean_absolute_error: 0.3295 - val_loss: 0.1817 - val_mean_absolute_error: 0.5751
# Epoch 84/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0810 - mean_absolute_error: 0.3274 - val_loss: 0.1832 - val_mean_absolute_error: 0.5777
# Epoch 85/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0800 - mean_absolute_error: 0.3252 - val_loss: 0.1848 - val_mean_absolute_error: 0.5806
# Epoch 86/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0790 - mean_absolute_error: 0.3227 - val_loss: 0.1867 - val_mean_absolute_error: 0.5837
# Epoch 87/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0778 - mean_absolute_error: 0.3200 - val_loss: 0.1886 - val_mean_absolute_error: 0.5870
# Epoch 88/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0766 - mean_absolute_error: 0.3171 - val_loss: 0.1908 - val_mean_absolute_error: 0.5908
# Epoch 89/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0753 - mean_absolute_error: 0.3141 - val_loss: 0.1932 - val_mean_absolute_error: 0.5949
# Epoch 90/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0739 - mean_absolute_error: 0.3107 - val_loss: 0.1958 - val_mean_absolute_error: 0.5993
# Epoch 91/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0723 - mean_absolute_error: 0.3071 - val_loss: 0.1987 - val_mean_absolute_error: 0.6041
# Epoch 92/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0707 - mean_absolute_error: 0.3034 - val_loss: 0.2018 - val_mean_absolute_error: 0.6093
# Epoch 93/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0690 - mean_absolute_error: 0.2996 - val_loss: 0.2052 - val_mean_absolute_error: 0.6149
# Epoch 94/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0673 - mean_absolute_error: 0.2953 - val_loss: 0.2091 - val_mean_absolute_error: 0.6212
# Epoch 95/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0654 - mean_absolute_error: 0.2908 - val_loss: 0.2133 - val_mean_absolute_error: 0.6280
# Epoch 96/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0635 - mean_absolute_error: 0.2860 - val_loss: 0.2177 - val_mean_absolute_error: 0.6351
# Epoch 97/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0617 - mean_absolute_error: 0.2818 - val_loss: 0.2224 - val_mean_absolute_error: 0.6425
# Epoch 98/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0599 - mean_absolute_error: 0.2772 - val_loss: 0.2270 - val_mean_absolute_error: 0.6498
# Epoch 99/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0581 - mean_absolute_error: 0.2727 - val_loss: 0.2316 - val_mean_absolute_error: 0.6568
# Epoch 100/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0565 - mean_absolute_error: 0.2687 - val_loss: 0.2362 - val_mean_absolute_error: 0.6638
# Epoch 101/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0550 - mean_absolute_error: 0.2651 - val_loss: 0.2404 - val_mean_absolute_error: 0.6703
# Epoch 102/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0534 - mean_absolute_error: 0.2616 - val_loss: 0.2445 - val_mean_absolute_error: 0.6765
# Epoch 103/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0523 - mean_absolute_error: 0.2586 - val_loss: 0.2488 - val_mean_absolute_error: 0.6830
# Epoch 104/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0511 - mean_absolute_error: 0.2558 - val_loss: 0.2529 - val_mean_absolute_error: 0.6890
# Epoch 105/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0502 - mean_absolute_error: 0.2536 - val_loss: 0.2562 - val_mean_absolute_error: 0.6939
# Epoch 106/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0494 - mean_absolute_error: 0.2519 - val_loss: 0.2585 - val_mean_absolute_error: 0.6973
# Epoch 107/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0488 - mean_absolute_error: 0.2509 - val_loss: 0.2598 - val_mean_absolute_error: 0.6993
# Epoch 108/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0483 - mean_absolute_error: 0.2502 - val_loss: 0.2599 - val_mean_absolute_error: 0.6994
# Epoch 109/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0480 - mean_absolute_error: 0.2502 - val_loss: 0.2580 - val_mean_absolute_error: 0.6969
# Epoch 110/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0476 - mean_absolute_error: 0.2500 - val_loss: 0.2537 - val_mean_absolute_error: 0.6907
# Epoch 111/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0472 - mean_absolute_error: 0.2490 - val_loss: 0.2465 - val_mean_absolute_error: 0.6802
# Epoch 112/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0466 - mean_absolute_error: 0.2474 - val_loss: 0.2361 - val_mean_absolute_error: 0.6647
# Epoch 113/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0458 - mean_absolute_error: 0.2450 - val_loss: 0.2232 - val_mean_absolute_error: 0.6450
# Epoch 114/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0449 - mean_absolute_error: 0.2418 - val_loss: 0.2093 - val_mean_absolute_error: 0.6231
# Epoch 115/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0439 - mean_absolute_error: 0.2384 - val_loss: 0.1943 - val_mean_absolute_error: 0.5986
# Epoch 116/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0430 - mean_absolute_error: 0.2348 - val_loss: 0.1785 - val_mean_absolute_error: 0.5717
# Epoch 117/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0420 - mean_absolute_error: 0.2314 - val_loss: 0.1625 - val_mean_absolute_error: 0.5431
# Epoch 118/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0411 - mean_absolute_error: 0.2281 - val_loss: 0.1482 - val_mean_absolute_error: 0.5163
# Epoch 119/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0401 - mean_absolute_error: 0.2249 - val_loss: 0.1366 - val_mean_absolute_error: 0.4934
# Epoch 120/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0389 - mean_absolute_error: 0.2217 - val_loss: 0.1266 - val_mean_absolute_error: 0.4726
# Epoch 121/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0377 - mean_absolute_error: 0.2186 - val_loss: 0.1159 - val_mean_absolute_error: 0.4494
# Epoch 122/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0366 - mean_absolute_error: 0.2168 - val_loss: 0.1025 - val_mean_absolute_error: 0.4182
# Epoch 123/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0357 - mean_absolute_error: 0.2146 - val_loss: 0.0863 - val_mean_absolute_error: 0.3773
# Epoch 124/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0344 - mean_absolute_error: 0.2105 - val_loss: 0.0677 - val_mean_absolute_error: 0.3240
# Epoch 125/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0332 - mean_absolute_error: 0.2048 - val_loss: 0.0496 - val_mean_absolute_error: 0.2650
# Epoch 126/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0323 - mean_absolute_error: 0.1999 - val_loss: 0.0368 - val_mean_absolute_error: 0.2209
# Epoch 127/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0315 - mean_absolute_error: 0.1966 - val_loss: 0.0284 - val_mean_absolute_error: 0.1873
# Epoch 128/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0308 - mean_absolute_error: 0.1940 - val_loss: 0.0234 - val_mean_absolute_error: 0.1663
# Epoch 129/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0305 - mean_absolute_error: 0.1941 - val_loss: 0.0202 - val_mean_absolute_error: 0.1537
# Epoch 130/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0307 - mean_absolute_error: 0.1946 - val_loss: 0.0179 - val_mean_absolute_error: 0.1477
# Epoch 131/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0304 - mean_absolute_error: 0.1915 - val_loss: 0.0167 - val_mean_absolute_error: 0.1457
# Epoch 132/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0299 - mean_absolute_error: 0.1879 - val_loss: 0.0166 - val_mean_absolute_error: 0.1447
# Epoch 133/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0296 - mean_absolute_error: 0.1874 - val_loss: 0.0168 - val_mean_absolute_error: 0.1434
# Epoch 134/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0291 - mean_absolute_error: 0.1863 - val_loss: 0.0171 - val_mean_absolute_error: 0.1430
# Epoch 135/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0286 - mean_absolute_error: 0.1847 - val_loss: 0.0182 - val_mean_absolute_error: 0.1457
# Epoch 136/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0282 - mean_absolute_error: 0.1847 - val_loss: 0.0182 - val_mean_absolute_error: 0.1461
# Epoch 137/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0279 - mean_absolute_error: 0.1821 - val_loss: 0.0212 - val_mean_absolute_error: 0.1599
# Epoch 138/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0271 - mean_absolute_error: 0.1826 - val_loss: 0.0260 - val_mean_absolute_error: 0.1807
# Epoch 139/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0273 - mean_absolute_error: 0.1850 - val_loss: 0.0204 - val_mean_absolute_error: 0.1574
# Epoch 140/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0260 - mean_absolute_error: 0.1769 - val_loss: 0.0172 - val_mean_absolute_error: 0.1432
# Epoch 141/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0254 - mean_absolute_error: 0.1747 - val_loss: 0.0143 - val_mean_absolute_error: 0.1307
# Epoch 142/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0247 - mean_absolute_error: 0.1709 - val_loss: 0.0166 - val_mean_absolute_error: 0.1405
# Epoch 143/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0247 - mean_absolute_error: 0.1761 - val_loss: 0.0151 - val_mean_absolute_error: 0.1341
# Epoch 144/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0229 - mean_absolute_error: 0.1666 - val_loss: 0.0106 - val_mean_absolute_error: 0.1123
# Epoch 145/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0257 - mean_absolute_error: 0.1728 - val_loss: 0.0113 - val_mean_absolute_error: 0.1157
# Epoch 146/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0222 - mean_absolute_error: 0.1633 - val_loss: 0.0099 - val_mean_absolute_error: 0.1085
# Epoch 147/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0220 - mean_absolute_error: 0.1634 - val_loss: 0.0077 - val_mean_absolute_error: 0.0972
# Epoch 148/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0276 - mean_absolute_error: 0.1840 - val_loss: 0.0126 - val_mean_absolute_error: 0.1286
# Epoch 149/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0462 - mean_absolute_error: 0.2532 - val_loss: 0.0315 - val_mean_absolute_error: 0.2239
# Epoch 150/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0250 - mean_absolute_error: 0.1776 - val_loss: 0.0230 - val_mean_absolute_error: 0.1716
# Epoch 151/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0432 - mean_absolute_error: 0.2498 - val_loss: 0.0089 - val_mean_absolute_error: 0.1094
# Epoch 152/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0201 - mean_absolute_error: 0.1582 - val_loss: 0.0104 - val_mean_absolute_error: 0.1098
# Epoch 153/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0199 - mean_absolute_error: 0.1540 - val_loss: 0.0152 - val_mean_absolute_error: 0.1345
# Epoch 154/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0196 - mean_absolute_error: 0.1569 - val_loss: 0.0087 - val_mean_absolute_error: 0.1099
# Epoch 155/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0196 - mean_absolute_error: 0.1536 - val_loss: 0.0104 - val_mean_absolute_error: 0.1246
# Epoch 156/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0270 - mean_absolute_error: 0.1835 - val_loss: 0.0382 - val_mean_absolute_error: 0.2487
# Epoch 157/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0597 - mean_absolute_error: 0.2990 - val_loss: 0.0503 - val_mean_absolute_error: 0.2713
# Epoch 158/250
# 316/316 [==============================] - 1s 2ms/step - loss: 2.7479 - mean_absolute_error: 3.2456 - val_loss: 18.2725 - val_mean_absolute_error: 18.7725
# Epoch 159/250
# 316/316 [==============================] - 1s 2ms/step - loss: 15.3813 - mean_absolute_error: 15.8813 - val_loss: 22.6319 - val_mean_absolute_error: 23.1319
# Epoch 160/250
# 316/316 [==============================] - 1s 3ms/step - loss: 19.3600 - mean_absolute_error: 19.8600 - val_loss: 20.4813 - val_mean_absolute_error: 20.9813
# Epoch 161/250
# 316/316 [==============================] - 1s 2ms/step - loss: 19.2939 - mean_absolute_error: 19.7939 - val_loss: 12.3775 - val_mean_absolute_error: 12.8775
# Epoch 162/250
# 316/316 [==============================] - 1s 2ms/step - loss: 15.6710 - mean_absolute_error: 16.1710 - val_loss: 0.3557 - val_mean_absolute_error: 0.8248
# Epoch 163/250
# 316/316 [==============================] - 1s 2ms/step - loss: 21.4581 - mean_absolute_error: 21.9577 - val_loss: 126.2337 - val_mean_absolute_error: 126.7337
# Epoch 164/250
# 316/316 [==============================] - 1s 2ms/step - loss: 110.9682 - mean_absolute_error: 111.4682 - val_loss: 109.3544 - val_mean_absolute_error: 109.8544
# Epoch 165/250
# 316/316 [==============================] - 1s 2ms/step - loss: 118.0005 - mean_absolute_error: 118.5005 - val_loss: 84.8718 - val_mean_absolute_error: 85.3718
# Epoch 166/250
# 316/316 [==============================] - 1s 2ms/step - loss: 86.1337 - mean_absolute_error: 86.6337 - val_loss: 130.7047 - val_mean_absolute_error: 131.2047
# Epoch 167/250
# 316/316 [==============================] - 1s 2ms/step - loss: 112.4168 - mean_absolute_error: 112.9168 - val_loss: 173.0045 - val_mean_absolute_error: 173.5045
# Epoch 168/250
# 316/316 [==============================] - 1s 2ms/step - loss: 182.5021 - mean_absolute_error: 183.0021 - val_loss: 114.5429 - val_mean_absolute_error: 115.0429
# Epoch 169/250
# 316/316 [==============================] - 1s 3ms/step - loss: 120.1947 - mean_absolute_error: 120.6947 - val_loss: 209.7215 - val_mean_absolute_error: 210.2215
# Epoch 170/250
# 316/316 [==============================] - 1s 2ms/step - loss: 185.7839 - mean_absolute_error: 186.2840 - val_loss: 204.0248 - val_mean_absolute_error: 204.5247
# Epoch 171/250
# 316/316 [==============================] - 1s 2ms/step - loss: 215.8430 - mean_absolute_error: 216.3431 - val_loss: 108.7553 - val_mean_absolute_error: 109.2553
# Epoch 172/250
# 316/316 [==============================] - 1s 2ms/step - loss: 137.7769 - mean_absolute_error: 138.2769 - val_loss: 359.9722 - val_mean_absolute_error: 360.4722
# Epoch 173/250
# 316/316 [==============================] - 1s 3ms/step - loss: 327.3208 - mean_absolute_error: 327.8207 - val_loss: 216.5465 - val_mean_absolute_error: 217.0465
# Epoch 174/250
# 316/316 [==============================] - 1s 2ms/step - loss: 232.2372 - mean_absolute_error: 232.7372 - val_loss: 75.2306 - val_mean_absolute_error: 75.7306
# Epoch 175/250
# 316/316 [==============================] - 1s 2ms/step - loss: 146.3463 - mean_absolute_error: 146.8464 - val_loss: 592.7397 - val_mean_absolute_error: 593.2396
# Epoch 176/250
# 316/316 [==============================] - 1s 2ms/step - loss: 547.3893 - mean_absolute_error: 547.8895 - val_loss: 217.6021 - val_mean_absolute_error: 218.1021
# Epoch 177/250
# 316/316 [==============================] - 1s 2ms/step - loss: 239.0787 - mean_absolute_error: 239.5786 - val_loss: 14.4040 - val_mean_absolute_error: 14.9040
# Epoch 178/250
# 316/316 [==============================] - 1s 2ms/step - loss: 149.9576 - mean_absolute_error: 150.4576 - val_loss: 932.4447 - val_mean_absolute_error: 932.9447
# Epoch 179/250
# 316/316 [==============================] - 1s 2ms/step - loss: 868.9504 - mean_absolute_error: 869.4502 - val_loss: 210.2543 - val_mean_absolute_error: 210.7543
# Epoch 180/250
# 316/316 [==============================] - 1s 2ms/step - loss: 240.0711 - mean_absolute_error: 240.5711 - val_loss: 77.6753 - val_mean_absolute_error: 78.1753
# Epoch 181/250
# 316/316 [==============================] - 1s 2ms/step - loss: 95.4383 - mean_absolute_error: 95.9383 - val_loss: 248.0898 - val_mean_absolute_error: 248.5898
# Epoch 182/250
# 316/316 [==============================] - 1s 2ms/step - loss: 219.4212 - mean_absolute_error: 219.9212 - val_loss: 314.7442 - val_mean_absolute_error: 315.2442
# Epoch 183/250
# 316/316 [==============================] - 1s 3ms/step - loss: 278.9120 - mean_absolute_error: 279.4119 - val_loss: 288.6433 - val_mean_absolute_error: 289.1432
# Epoch 184/250
# 316/316 [==============================] - 1s 2ms/step - loss: 281.1808 - mean_absolute_error: 281.6808 - val_loss: 177.6379 - val_mean_absolute_error: 178.1379
# Epoch 185/250
# 316/316 [==============================] - 1s 2ms/step - loss: 231.5116 - mean_absolute_error: 232.0116 - val_loss: 12.1050 - val_mean_absolute_error: 12.6050
# Epoch 186/250
# 316/316 [==============================] - 1s 2ms/step - loss: 304.5009 - mean_absolute_error: 305.0010 - val_loss: 1799.8494 - val_mean_absolute_error: 1800.3492
# Epoch 187/250
# 316/316 [==============================] - 1s 2ms/step - loss: 1595.5922 - mean_absolute_error: 1596.0921 - val_loss: 1532.0198 - val_mean_absolute_error: 1532.5199
# Epoch 188/250
# 316/316 [==============================] - 1s 2ms/step - loss: 1642.9470 - mean_absolute_error: 1643.4474 - val_loss: 1178.8831 - val_mean_absolute_error: 1179.3832
# Epoch 189/250
# 316/316 [==============================] - 1s 2ms/step - loss: 1200.9779 - mean_absolute_error: 1201.4783 - val_loss: 1885.2629 - val_mean_absolute_error: 1885.7629
# Epoch 190/250
# 316/316 [==============================] - 1s 2ms/step - loss: 1637.8907 - mean_absolute_error: 1638.3908 - val_loss: 2413.0737 - val_mean_absolute_error: 2413.5735
# Epoch 191/250
# 316/316 [==============================] - 1s 2ms/step - loss: 2536.3697 - mean_absolute_error: 2536.8697 - val_loss: 1583.3965 - val_mean_absolute_error: 1583.8965
# Epoch 192/250
# 316/316 [==============================] - 1s 2ms/step - loss: 1672.3615 - mean_absolute_error: 1672.8611 - val_loss: 3013.2324 - val_mean_absolute_error: 3013.7324
# Epoch 193/250
# 316/316 [==============================] - 1s 2ms/step - loss: 2685.8319 - mean_absolute_error: 2686.3323 - val_loss: 2841.6658 - val_mean_absolute_error: 2842.1655
# Epoch 194/250
# 316/316 [==============================] - 1s 2ms/step - loss: 2997.9255 - mean_absolute_error: 2998.4256 - val_loss: 1493.8840 - val_mean_absolute_error: 1494.3842
# Epoch 195/250
# 316/316 [==============================] - 1s 2ms/step - loss: 1915.6815 - mean_absolute_error: 1916.1818 - val_loss: 5141.8633 - val_mean_absolute_error: 5142.3633
# Epoch 196/250
# 316/316 [==============================] - 1s 2ms/step - loss: 4691.2576 - mean_absolute_error: 4691.7557 - val_loss: 3013.4490 - val_mean_absolute_error: 3013.9487
# Epoch 197/250
# 316/316 [==============================] - 1s 3ms/step - loss: 3224.5045 - mean_absolute_error: 3225.0049 - val_loss: 1016.2125 - val_mean_absolute_error: 1016.7125
# Epoch 198/250
# 316/316 [==============================] - 1s 2ms/step - loss: 2034.8787 - mean_absolute_error: 2035.3785 - val_loss: 8433.1318 - val_mean_absolute_error: 8433.6318
# Epoch 199/250
# 316/316 [==============================] - 1s 2ms/step - loss: 7803.0877 - mean_absolute_error: 7803.5885 - val_loss: 3025.6560 - val_mean_absolute_error: 3026.1558
# Epoch 200/250
# 316/316 [==============================] - 1s 2ms/step - loss: 3318.4875 - mean_absolute_error: 3318.9885 - val_loss: 154.8240 - val_mean_absolute_error: 155.3240
# Epoch 201/250
# 316/316 [==============================] - 1s 2ms/step - loss: 2083.9284 - mean_absolute_error: 2084.4284 - val_loss: 13233.3691 - val_mean_absolute_error: 13233.8691
# Epoch 202/250
# 316/316 [==============================] - 1s 2ms/step - loss: 12346.9872 - mean_absolute_error: 12347.4914 - val_loss: 2920.4316 - val_mean_absolute_error: 2920.9316
# Epoch 203/250
# 316/316 [==============================] - 1s 2ms/step - loss: 3331.1026 - mean_absolute_error: 3331.6026 - val_loss: 1160.1163 - val_mean_absolute_error: 1160.6165
# Epoch 204/250
# 316/316 [==============================] - 1s 2ms/step - loss: 1395.8302 - mean_absolute_error: 1396.3302 - val_loss: 3567.5347 - val_mean_absolute_error: 3568.0344
# Epoch 205/250
# 316/316 [==============================] - 1s 2ms/step - loss: 3147.4592 - mean_absolute_error: 3147.9598 - val_loss: 4509.2549 - val_mean_absolute_error: 4509.7554
# Epoch 206/250
# 316/316 [==============================] - 1s 2ms/step - loss: 3988.1220 - mean_absolute_error: 3988.6209 - val_loss: 4140.7354 - val_mean_absolute_error: 4141.2358
# Epoch 207/250
# 316/316 [==============================] - 1s 2ms/step - loss: 4020.3418 - mean_absolute_error: 4020.8410 - val_loss: 2572.8789 - val_mean_absolute_error: 2573.3789
# Epoch 208/250
# 316/316 [==============================] - 1s 2ms/step - loss: 3318.5788 - mean_absolute_error: 3319.0788 - val_loss: 120.3268 - val_mean_absolute_error: 120.8268
# Epoch 209/250
# 316/316 [==============================] - 1s 2ms/step - loss: 4265.7524 - mean_absolute_error: 4266.2524 - val_loss: 25487.4238 - val_mean_absolute_error: 25487.9258
# Epoch 210/250
# 316/316 [==============================] - 1s 2ms/step - loss: 22612.6860 - mean_absolute_error: 22613.1941 - val_loss: 21589.5352 - val_mean_absolute_error: 21590.0371
# Epoch 211/250
# 316/316 [==============================] - 1s 3ms/step - loss: 23145.9470 - mean_absolute_error: 23146.4521 - val_loss: 16601.2852 - val_mean_absolute_error: 16601.7871
# Epoch 212/250
# 316/316 [==============================] - 1s 2ms/step - loss: 16928.8047 - mean_absolute_error: 16929.2999 - val_loss: 26694.0898 - val_mean_absolute_error: 26694.5879
# Epoch 213/250
# 316/316 [==============================] - 1s 2ms/step - loss: 23210.3450 - mean_absolute_error: 23210.8387 - val_loss: 34034.6211 - val_mean_absolute_error: 34035.1172
# Epoch 214/250
# 316/316 [==============================] - 1s 2ms/step - loss: 35765.7602 - mean_absolute_error: 35766.2546 - val_loss: 22315.0957 - val_mean_absolute_error: 22315.5977
# Epoch 215/250
# 316/316 [==============================] - 1s 2ms/step - loss: 23586.8397 - mean_absolute_error: 23587.3449 - val_loss: 42627.1562 - val_mean_absolute_error: 42627.6562
# Epoch 216/250
# 316/316 [==============================] - 1s 2ms/step - loss: 38012.9903 - mean_absolute_error: 38013.4808 - val_loss: 40088.5625 - val_mean_absolute_error: 40089.0625
# Epoch 217/250
# 316/316 [==============================] - 1s 2ms/step - loss: 42285.3336 - mean_absolute_error: 42285.8241 - val_loss: 21050.6133 - val_mean_absolute_error: 21051.1152
# Epoch 218/250
# 316/316 [==============================] - 1s 2ms/step - loss: 27024.0108 - mean_absolute_error: 27024.5077 - val_loss: 72694.9531 - val_mean_absolute_error: 72695.4609
# Epoch 219/250
# 316/316 [==============================] - 1s 2ms/step - loss: 66340.4343 - mean_absolute_error: 66340.9407 - val_loss: 42514.9922 - val_mean_absolute_error: 42515.4883
# Epoch 220/250
# 316/316 [==============================] - 1s 2ms/step - loss: 45485.7562 - mean_absolute_error: 45486.2570 - val_loss: 14303.2656 - val_mean_absolute_error: 14303.7656
# Epoch 221/250
# 316/316 [==============================] - 1s 2ms/step - loss: 28707.6827 - mean_absolute_error: 28708.1818 - val_loss: 119185.3750 - val_mean_absolute_error: 119185.8750
# Epoch 222/250
# 316/316 [==============================] - 1s 2ms/step - loss: 110296.2199 - mean_absolute_error: 110296.7516 - val_loss: 42687.4336 - val_mean_absolute_error: 42687.9297
# Epoch 223/250
# 316/316 [==============================] - 1s 2ms/step - loss: 46813.3399 - mean_absolute_error: 46813.8304 - val_loss: 2135.8628 - val_mean_absolute_error: 2136.3625
# Epoch 224/250
# 316/316 [==============================] - 1s 3ms/step - loss: 29400.6017 - mean_absolute_error: 29401.0993 - val_loss: 186990.4844 - val_mean_absolute_error: 186990.9844
# Epoch 225/250
# 316/316 [==============================] - 1s 2ms/step - loss: 174480.5374 - mean_absolute_error: 174481.0627 - val_loss: 41201.1250 - val_mean_absolute_error: 41201.6250
# Epoch 226/250
# 316/316 [==============================] - 1s 2ms/step - loss: 46991.5313 - mean_absolute_error: 46992.0313 - val_loss: 16451.2812 - val_mean_absolute_error: 16451.7812
# Epoch 227/250
# 316/316 [==============================] - 1s 2ms/step - loss: 19765.5419 - mean_absolute_error: 19766.0395 - val_loss: 50456.9688 - val_mean_absolute_error: 50457.4688
# Epoch 228/250
# 316/316 [==============================] - 1s 2ms/step - loss: 44508.0638 - mean_absolute_error: 44508.5733 - val_loss: 63759.1445 - val_mean_absolute_error: 63759.6445
# Epoch 229/250
# 316/316 [==============================] - 1s 2ms/step - loss: 56382.7040 - mean_absolute_error: 56383.1913 - val_loss: 58553.6445 - val_mean_absolute_error: 58554.1445
# Epoch 230/250
# 316/316 [==============================] - 1s 2ms/step - loss: 56837.8425 - mean_absolute_error: 56838.3274 - val_loss: 36407.0625 - val_mean_absolute_error: 36407.5625
# Epoch 231/250
# 316/316 [==============================] - 1s 2ms/step - loss: 46925.1367 - mean_absolute_error: 46925.6462 - val_loss: 1648.6077 - val_mean_absolute_error: 1649.1078
# Epoch 232/250
# 316/316 [==============================] - 1s 2ms/step - loss: 60219.5698 - mean_absolute_error: 60220.0634 - val_loss: 360083.5000 - val_mean_absolute_error: 360084.0000
# Epoch 233/250
# 316/316 [==============================] - 1s 2ms/step - loss: 319487.4949 - mean_absolute_error: 319487.8683 - val_loss: 304909.4375 - val_mean_absolute_error: 304909.9062
# Epoch 234/250
# 316/316 [==============================] - 1s 2ms/step - loss: 326883.8062 - mean_absolute_error: 326884.3762 - val_loss: 234448.5312 - val_mean_absolute_error: 234449.0469
# Epoch 235/250
# 316/316 [==============================] - 1s 2ms/step - loss: 239090.2678 - mean_absolute_error: 239090.7455 - val_loss: 377128.1875 - val_mean_absolute_error: 377128.6562
# Epoch 236/250
# 316/316 [==============================] - 1s 2ms/step - loss: 327929.2942 - mean_absolute_error: 327929.8448 - val_loss: 480700.5625 - val_mean_absolute_error: 480701.0938
# Epoch 237/250
# 316/316 [==============================] - 1s 2ms/step - loss: 505142.9193 - mean_absolute_error: 505143.5459 - val_loss: 315157.7812 - val_mean_absolute_error: 315158.3125
# Epoch 238/250
# 316/316 [==============================] - 1s 3ms/step - loss: 333137.4541 - mean_absolute_error: 333137.9288 - val_loss: 602189.1250 - val_mean_absolute_error: 602189.7500
# Epoch 239/250
# 316/316 [==============================] - 1s 2ms/step - loss: 537022.5002 - mean_absolute_error: 537023.2027 - val_loss: 566214.5625 - val_mean_absolute_error: 566215.1250
# Epoch 240/250
# 316/316 [==============================] - 1s 2ms/step - loss: 597234.4802 - mean_absolute_error: 597234.7896 - val_loss: 297296.5000 - val_mean_absolute_error: 297297.0000
# Epoch 241/250
# 316/316 [==============================] - 1s 2ms/step - loss: 381688.4771 - mean_absolute_error: 381688.9399 - val_loss: 1026908.0000 - val_mean_absolute_error: 1026908.6250
# Epoch 242/250
# 316/316 [==============================] - 1s 2ms/step - loss: 937158.7919 - mean_absolute_error: 937159.0775 - val_loss: 600488.8750 - val_mean_absolute_error: 600489.2500
# Epoch 243/250
# 316/316 [==============================] - 1s 2ms/step - loss: 642441.7983 - mean_absolute_error: 642442.0839 - val_loss: 201987.3906 - val_mean_absolute_error: 201987.9062
# Epoch 244/250
# 316/316 [==============================] - 1s 2ms/step - loss: 405470.8987 - mean_absolute_error: 405471.4367 - val_loss: 1683603.2500 - val_mean_absolute_error: 1683603.6250
# Epoch 245/250
# 316/316 [==============================] - 1s 3ms/step - loss: 1558051.6883 - mean_absolute_error: 1558052.0870 - val_loss: 602924.0000 - val_mean_absolute_error: 602924.5000
# Epoch 246/250
# 316/316 [==============================] - 1s 2ms/step - loss: 661193.4043 - mean_absolute_error: 661193.9280 - val_loss: 30117.5742 - val_mean_absolute_error: 30118.0742
# Epoch 247/250
# 316/316 [==============================] - 1s 2ms/step - loss: 415257.9478 - mean_absolute_error: 415258.4715 - val_loss: 2641376.5000 - val_mean_absolute_error: 2641377.2500
# Epoch 248/250
# 316/316 [==============================] - 1s 2ms/step - loss: 2464680.0348 - mean_absolute_error: 2464680.1297 - val_loss: 581928.4375 - val_mean_absolute_error: 581928.8750
# Epoch 249/250
# 316/316 [==============================] - 1s 2ms/step - loss: 663709.5047 - mean_absolute_error: 663710.0522 - val_loss: 232447.0312 - val_mean_absolute_error: 232447.5469
# Epoch 250/250
# 316/316 [==============================] - 1s 3ms/step - loss: 279245.8758 - mean_absolute_error: 279246.3125 - val_loss: 712790.5625 - val_mean_absolute_error: 712791.1250

# %%
plt.semilogx(history.history['lr'], history.history['val_loss'])
plt.legend(['Learning Rate', 'Validation Loss'])

# %%
plt.semilogx(history.history['lr'][:140], history.history['loss'][:140])

# %% [markdown]
# It looks like the learning rate of 0.1 seems to work the best. Let's use that learning rate and train the network this time for real. Once we train the network, let's predict the prices for the training and test data.

# %%
# Observing the above graph, 0.1 seems to be the best learning rate
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])


optimizer = SGD(lr=0.1, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, validation_data=(X_test_reshape, y_test_reshape))
# Out:
# Train on 316 samples, validate on 80 samples
# Epoch 1/250
# 316/316 [==============================] - 3s 8ms/step - loss: 0.0823 - mean_absolute_error: 0.3254 - val_loss: 0.3384 - val_mean_absolute_error: 0.8058
# Epoch 2/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0675 - mean_absolute_error: 0.3054 - val_loss: 0.1416 - val_mean_absolute_error: 0.5029
# Epoch 3/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0398 - mean_absolute_error: 0.2232 - val_loss: 0.0309 - val_mean_absolute_error: 0.2023
# Epoch 4/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0471 - mean_absolute_error: 0.2365 - val_loss: 0.0295 - val_mean_absolute_error: 0.1891
# Epoch 5/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0354 - mean_absolute_error: 0.2152 - val_loss: 0.0175 - val_mean_absolute_error: 0.1526
# Epoch 6/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0320 - mean_absolute_error: 0.1972 - val_loss: 0.0192 - val_mean_absolute_error: 0.1616
# Epoch 7/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0387 - mean_absolute_error: 0.2089 - val_loss: 0.0152 - val_mean_absolute_error: 0.1387
# Epoch 8/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0284 - mean_absolute_error: 0.1830 - val_loss: 0.0318 - val_mean_absolute_error: 0.2008
# Epoch 9/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0341 - mean_absolute_error: 0.2139 - val_loss: 0.0350 - val_mean_absolute_error: 0.2191
# Epoch 10/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0294 - mean_absolute_error: 0.1878 - val_loss: 0.0345 - val_mean_absolute_error: 0.2197
# Epoch 11/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0330 - mean_absolute_error: 0.1989 - val_loss: 0.0444 - val_mean_absolute_error: 0.2548
# Epoch 12/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0284 - mean_absolute_error: 0.1907 - val_loss: 0.0323 - val_mean_absolute_error: 0.2076
# Epoch 13/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0276 - mean_absolute_error: 0.1877 - val_loss: 0.0135 - val_mean_absolute_error: 0.1255
# Epoch 14/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0268 - mean_absolute_error: 0.1753 - val_loss: 0.0117 - val_mean_absolute_error: 0.1247
# Epoch 15/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0269 - mean_absolute_error: 0.1750 - val_loss: 0.0121 - val_mean_absolute_error: 0.1304
# Epoch 16/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0276 - mean_absolute_error: 0.1846 - val_loss: 0.0116 - val_mean_absolute_error: 0.1241
# Epoch 17/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0257 - mean_absolute_error: 0.1786 - val_loss: 0.0108 - val_mean_absolute_error: 0.1133
# Epoch 18/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0257 - mean_absolute_error: 0.1724 - val_loss: 0.0146 - val_mean_absolute_error: 0.1325
# Epoch 19/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0229 - mean_absolute_error: 0.1663 - val_loss: 0.0210 - val_mean_absolute_error: 0.1624
# Epoch 20/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0239 - mean_absolute_error: 0.1754 - val_loss: 0.0196 - val_mean_absolute_error: 0.1568
# Epoch 21/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0224 - mean_absolute_error: 0.1671 - val_loss: 0.0144 - val_mean_absolute_error: 0.1309
# Epoch 22/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0216 - mean_absolute_error: 0.1612 - val_loss: 0.0120 - val_mean_absolute_error: 0.1192
# Epoch 23/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0208 - mean_absolute_error: 0.1588 - val_loss: 0.0109 - val_mean_absolute_error: 0.1127
# Epoch 24/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0207 - mean_absolute_error: 0.1609 - val_loss: 0.0101 - val_mean_absolute_error: 0.1084
# Epoch 25/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0202 - mean_absolute_error: 0.1586 - val_loss: 0.0105 - val_mean_absolute_error: 0.1102
# Epoch 26/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0197 - mean_absolute_error: 0.1554 - val_loss: 0.0145 - val_mean_absolute_error: 0.1317
# Epoch 27/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0197 - mean_absolute_error: 0.1580 - val_loss: 0.0162 - val_mean_absolute_error: 0.1429
# Epoch 28/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0195 - mean_absolute_error: 0.1560 - val_loss: 0.0152 - val_mean_absolute_error: 0.1384
# Epoch 29/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0187 - mean_absolute_error: 0.1521 - val_loss: 0.0135 - val_mean_absolute_error: 0.1262
# Epoch 30/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0194 - mean_absolute_error: 0.1568 - val_loss: 0.0085 - val_mean_absolute_error: 0.0976
# Epoch 31/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0184 - mean_absolute_error: 0.1508 - val_loss: 0.0068 - val_mean_absolute_error: 0.0906
# Epoch 32/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0185 - mean_absolute_error: 0.1498 - val_loss: 0.0074 - val_mean_absolute_error: 0.0916
# Epoch 33/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0174 - mean_absolute_error: 0.1470 - val_loss: 0.0090 - val_mean_absolute_error: 0.0994
# Epoch 34/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0171 - mean_absolute_error: 0.1456 - val_loss: 0.0119 - val_mean_absolute_error: 0.1190
# Epoch 35/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0170 - mean_absolute_error: 0.1462 - val_loss: 0.0122 - val_mean_absolute_error: 0.1216
# Epoch 36/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0167 - mean_absolute_error: 0.1454 - val_loss: 0.0081 - val_mean_absolute_error: 0.0938
# Epoch 37/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_absolute_error: 0.1426 - val_loss: 0.0060 - val_mean_absolute_error: 0.0851
# Epoch 38/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0160 - mean_absolute_error: 0.1403 - val_loss: 0.0066 - val_mean_absolute_error: 0.0937
# Epoch 39/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_absolute_error: 0.1393 - val_loss: 0.0065 - val_mean_absolute_error: 0.0928
# Epoch 40/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0158 - mean_absolute_error: 0.1396 - val_loss: 0.0060 - val_mean_absolute_error: 0.0885
# Epoch 41/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0163 - mean_absolute_error: 0.1414 - val_loss: 0.0057 - val_mean_absolute_error: 0.0833
# Epoch 42/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0153 - mean_absolute_error: 0.1367 - val_loss: 0.0064 - val_mean_absolute_error: 0.0835
# Epoch 43/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_absolute_error: 0.1418 - val_loss: 0.0061 - val_mean_absolute_error: 0.0815
# Epoch 44/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0146 - mean_absolute_error: 0.1352 - val_loss: 0.0055 - val_mean_absolute_error: 0.0781
# Epoch 45/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.1363 - val_loss: 0.0055 - val_mean_absolute_error: 0.0798
# Epoch 46/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0141 - mean_absolute_error: 0.1331 - val_loss: 0.0059 - val_mean_absolute_error: 0.0872
# Epoch 47/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0144 - mean_absolute_error: 0.1339 - val_loss: 0.0070 - val_mean_absolute_error: 0.1009
# Epoch 48/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0137 - mean_absolute_error: 0.1303 - val_loss: 0.0084 - val_mean_absolute_error: 0.1137
# Epoch 49/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0138 - mean_absolute_error: 0.1304 - val_loss: 0.0081 - val_mean_absolute_error: 0.1113
# Epoch 50/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0135 - mean_absolute_error: 0.1292 - val_loss: 0.0059 - val_mean_absolute_error: 0.0891
# Epoch 51/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.1329 - val_loss: 0.0054 - val_mean_absolute_error: 0.0820
# Epoch 52/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0136 - mean_absolute_error: 0.1298 - val_loss: 0.0065 - val_mean_absolute_error: 0.0985
# Epoch 53/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0134 - mean_absolute_error: 0.1283 - val_loss: 0.0095 - val_mean_absolute_error: 0.1214
# Epoch 54/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0131 - mean_absolute_error: 0.1273 - val_loss: 0.0117 - val_mean_absolute_error: 0.1360
# Epoch 55/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0129 - mean_absolute_error: 0.1254 - val_loss: 0.0102 - val_mean_absolute_error: 0.1270
# Epoch 56/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.1257 - val_loss: 0.0071 - val_mean_absolute_error: 0.1042
# Epoch 57/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0126 - mean_absolute_error: 0.1258 - val_loss: 0.0054 - val_mean_absolute_error: 0.0845
# Epoch 58/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0129 - mean_absolute_error: 0.1279 - val_loss: 0.0051 - val_mean_absolute_error: 0.0806
# Epoch 59/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0126 - mean_absolute_error: 0.1265 - val_loss: 0.0060 - val_mean_absolute_error: 0.0938
# Epoch 60/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0125 - mean_absolute_error: 0.1248 - val_loss: 0.0086 - val_mean_absolute_error: 0.1155
# Epoch 61/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.1233 - val_loss: 0.0105 - val_mean_absolute_error: 0.1285
# Epoch 62/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0122 - mean_absolute_error: 0.1226 - val_loss: 0.0114 - val_mean_absolute_error: 0.1345
# Epoch 63/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0121 - mean_absolute_error: 0.1218 - val_loss: 0.0135 - val_mean_absolute_error: 0.1469
# Epoch 64/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0122 - mean_absolute_error: 0.1222 - val_loss: 0.0106 - val_mean_absolute_error: 0.1292
# Epoch 65/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0120 - mean_absolute_error: 0.1215 - val_loss: 0.0067 - val_mean_absolute_error: 0.1009
# Epoch 66/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0121 - mean_absolute_error: 0.1223 - val_loss: 0.0070 - val_mean_absolute_error: 0.1034
# Epoch 67/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0117 - mean_absolute_error: 0.1210 - val_loss: 0.0094 - val_mean_absolute_error: 0.1211
# Epoch 68/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0120 - mean_absolute_error: 0.1217 - val_loss: 0.0077 - val_mean_absolute_error: 0.1084
# Epoch 69/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0119 - mean_absolute_error: 0.1208 - val_loss: 0.0052 - val_mean_absolute_error: 0.0860
# Epoch 70/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0119 - mean_absolute_error: 0.1220 - val_loss: 0.0047 - val_mean_absolute_error: 0.0774
# Epoch 71/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.1207 - val_loss: 0.0060 - val_mean_absolute_error: 0.0947
# Epoch 72/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0115 - mean_absolute_error: 0.1182 - val_loss: 0.0122 - val_mean_absolute_error: 0.1395
# Epoch 73/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0117 - mean_absolute_error: 0.1187 - val_loss: 0.0180 - val_mean_absolute_error: 0.1719
# Epoch 74/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0116 - mean_absolute_error: 0.1172 - val_loss: 0.0175 - val_mean_absolute_error: 0.1699
# Epoch 75/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.1232 - val_loss: 0.0064 - val_mean_absolute_error: 0.0982
# Epoch 76/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0113 - mean_absolute_error: 0.1177 - val_loss: 0.0044 - val_mean_absolute_error: 0.0723
# Epoch 77/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0115 - mean_absolute_error: 0.1193 - val_loss: 0.0044 - val_mean_absolute_error: 0.0741
# Epoch 78/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0113 - mean_absolute_error: 0.1180 - val_loss: 0.0076 - val_mean_absolute_error: 0.1073
# Epoch 79/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.1153 - val_loss: 0.0157 - val_mean_absolute_error: 0.1595
# Epoch 80/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.1160 - val_loss: 0.0161 - val_mean_absolute_error: 0.1616
# Epoch 81/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0111 - mean_absolute_error: 0.1142 - val_loss: 0.0109 - val_mean_absolute_error: 0.1310
# Epoch 82/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.1156 - val_loss: 0.0058 - val_mean_absolute_error: 0.0928
# Epoch 83/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0107 - mean_absolute_error: 0.1142 - val_loss: 0.0046 - val_mean_absolute_error: 0.0783
# Epoch 84/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.1157 - val_loss: 0.0045 - val_mean_absolute_error: 0.0746
# Epoch 85/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.1168 - val_loss: 0.0061 - val_mean_absolute_error: 0.0951
# Epoch 86/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.1143 - val_loss: 0.0127 - val_mean_absolute_error: 0.1423
# Epoch 87/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.1176 - val_loss: 0.0108 - val_mean_absolute_error: 0.1294
# Epoch 88/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0115 - mean_absolute_error: 0.1151 - val_loss: 0.0107 - val_mean_absolute_error: 0.1292
# Epoch 89/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0113 - mean_absolute_error: 0.1182 - val_loss: 0.0058 - val_mean_absolute_error: 0.0931
# Epoch 90/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0106 - mean_absolute_error: 0.1134 - val_loss: 0.0045 - val_mean_absolute_error: 0.0745
# Epoch 91/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0112 - mean_absolute_error: 0.1174 - val_loss: 0.0059 - val_mean_absolute_error: 0.0938
# Epoch 92/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0124 - mean_absolute_error: 0.1251 - val_loss: 0.0055 - val_mean_absolute_error: 0.0894
# Epoch 93/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0107 - mean_absolute_error: 0.1127 - val_loss: 0.0073 - val_mean_absolute_error: 0.1046
# Epoch 94/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0106 - mean_absolute_error: 0.1111 - val_loss: 0.0092 - val_mean_absolute_error: 0.1188
# Epoch 95/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.1121 - val_loss: 0.0065 - val_mean_absolute_error: 0.0986
# Epoch 96/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.1097 - val_loss: 0.0058 - val_mean_absolute_error: 0.0924
# Epoch 97/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0099 - mean_absolute_error: 0.1094 - val_loss: 0.0050 - val_mean_absolute_error: 0.0840
# Epoch 98/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0100 - mean_absolute_error: 0.1093 - val_loss: 0.0063 - val_mean_absolute_error: 0.0963
# Epoch 99/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0101 - mean_absolute_error: 0.1108 - val_loss: 0.0075 - val_mean_absolute_error: 0.1058
# Epoch 100/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0098 - mean_absolute_error: 0.1075 - val_loss: 0.0071 - val_mean_absolute_error: 0.1022
# Epoch 101/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0098 - mean_absolute_error: 0.1077 - val_loss: 0.0069 - val_mean_absolute_error: 0.1014
# Epoch 102/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0101 - mean_absolute_error: 0.1113 - val_loss: 0.0050 - val_mean_absolute_error: 0.0831
# Epoch 103/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0099 - mean_absolute_error: 0.1080 - val_loss: 0.0046 - val_mean_absolute_error: 0.0785
# Epoch 104/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0099 - mean_absolute_error: 0.1081 - val_loss: 0.0056 - val_mean_absolute_error: 0.0897
# Epoch 105/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0096 - mean_absolute_error: 0.1067 - val_loss: 0.0071 - val_mean_absolute_error: 0.1016
# Epoch 106/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0098 - mean_absolute_error: 0.1065 - val_loss: 0.0094 - val_mean_absolute_error: 0.1204
# Epoch 107/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0097 - mean_absolute_error: 0.1087 - val_loss: 0.0067 - val_mean_absolute_error: 0.0985
# Epoch 108/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0097 - mean_absolute_error: 0.1061 - val_loss: 0.0055 - val_mean_absolute_error: 0.0885
# Epoch 109/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0099 - mean_absolute_error: 0.1101 - val_loss: 0.0044 - val_mean_absolute_error: 0.0756
# Epoch 110/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.1075 - val_loss: 0.0044 - val_mean_absolute_error: 0.0758
# Epoch 111/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.1069 - val_loss: 0.0057 - val_mean_absolute_error: 0.0904
# Epoch 112/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.1068 - val_loss: 0.0068 - val_mean_absolute_error: 0.0992
# Epoch 113/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0092 - mean_absolute_error: 0.1039 - val_loss: 0.0088 - val_mean_absolute_error: 0.1154
# Epoch 114/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0097 - mean_absolute_error: 0.1081 - val_loss: 0.0069 - val_mean_absolute_error: 0.0996
# Epoch 115/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.1045 - val_loss: 0.0067 - val_mean_absolute_error: 0.0991
# Epoch 116/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.1063 - val_loss: 0.0080 - val_mean_absolute_error: 0.1101
# Epoch 117/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0103 - mean_absolute_error: 0.1134 - val_loss: 0.0060 - val_mean_absolute_error: 0.0915
# Epoch 118/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.1129 - val_loss: 0.0071 - val_mean_absolute_error: 0.1023
# Epoch 119/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.1089 - val_loss: 0.0064 - val_mean_absolute_error: 0.0960
# Epoch 120/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.1048 - val_loss: 0.0064 - val_mean_absolute_error: 0.0957
# Epoch 121/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0098 - mean_absolute_error: 0.1074 - val_loss: 0.0089 - val_mean_absolute_error: 0.1164
# Epoch 122/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.1143 - val_loss: 0.0050 - val_mean_absolute_error: 0.0824
# Epoch 123/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.1036 - val_loss: 0.0045 - val_mean_absolute_error: 0.0778
# Epoch 124/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0090 - mean_absolute_error: 0.1027 - val_loss: 0.0051 - val_mean_absolute_error: 0.0846
# Epoch 125/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.1019 - val_loss: 0.0067 - val_mean_absolute_error: 0.0979
# Epoch 126/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.1027 - val_loss: 0.0127 - val_mean_absolute_error: 0.1422
# Epoch 127/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.1077 - val_loss: 0.0101 - val_mean_absolute_error: 0.1238
# Epoch 128/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.1002 - val_loss: 0.0055 - val_mean_absolute_error: 0.0880
# Epoch 129/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.1037 - val_loss: 0.0048 - val_mean_absolute_error: 0.0823
# Epoch 130/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0097 - mean_absolute_error: 0.1093 - val_loss: 0.0044 - val_mean_absolute_error: 0.0778
# Epoch 131/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.1070 - val_loss: 0.0045 - val_mean_absolute_error: 0.0771
# Epoch 132/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.1015 - val_loss: 0.0071 - val_mean_absolute_error: 0.1017
# Epoch 133/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.1042 - val_loss: 0.0080 - val_mean_absolute_error: 0.1090
# Epoch 134/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.1019 - val_loss: 0.0057 - val_mean_absolute_error: 0.0875
# Epoch 135/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.1041 - val_loss: 0.0074 - val_mean_absolute_error: 0.1050
# Epoch 136/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.1079 - val_loss: 0.0071 - val_mean_absolute_error: 0.1017
# Epoch 137/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.1000 - val_loss: 0.0054 - val_mean_absolute_error: 0.0860
# Epoch 138/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0091 - mean_absolute_error: 0.1022 - val_loss: 0.0070 - val_mean_absolute_error: 0.1019
# Epoch 139/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.1075 - val_loss: 0.0063 - val_mean_absolute_error: 0.0947
# Epoch 140/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0995 - val_loss: 0.0068 - val_mean_absolute_error: 0.0991
# Epoch 141/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0087 - mean_absolute_error: 0.1003 - val_loss: 0.0060 - val_mean_absolute_error: 0.0924
# Epoch 142/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0994 - val_loss: 0.0048 - val_mean_absolute_error: 0.0786
# Epoch 143/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.1025 - val_loss: 0.0077 - val_mean_absolute_error: 0.1071
# Epoch 144/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0101 - mean_absolute_error: 0.1119 - val_loss: 0.0061 - val_mean_absolute_error: 0.0926
# Epoch 145/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0976 - val_loss: 0.0051 - val_mean_absolute_error: 0.0813
# Epoch 146/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.1009 - val_loss: 0.0056 - val_mean_absolute_error: 0.0883
# Epoch 147/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.1014 - val_loss: 0.0047 - val_mean_absolute_error: 0.0780
# Epoch 148/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0972 - val_loss: 0.0046 - val_mean_absolute_error: 0.0778
# Epoch 149/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0992 - val_loss: 0.0050 - val_mean_absolute_error: 0.0812
# Epoch 150/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0986 - val_loss: 0.0077 - val_mean_absolute_error: 0.1057
# Epoch 151/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.0985 - val_loss: 0.0118 - val_mean_absolute_error: 0.1361
# Epoch 152/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.1001 - val_loss: 0.0084 - val_mean_absolute_error: 0.1116
# Epoch 153/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0959 - val_loss: 0.0050 - val_mean_absolute_error: 0.0824
# Epoch 154/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0971 - val_loss: 0.0045 - val_mean_absolute_error: 0.0772
# Epoch 155/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0965 - val_loss: 0.0072 - val_mean_absolute_error: 0.1025
# Epoch 156/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0951 - val_loss: 0.0111 - val_mean_absolute_error: 0.1310
# Epoch 157/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0985 - val_loss: 0.0084 - val_mean_absolute_error: 0.1108
# Epoch 158/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0965 - val_loss: 0.0060 - val_mean_absolute_error: 0.0922
# Epoch 159/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0965 - val_loss: 0.0047 - val_mean_absolute_error: 0.0806
# Epoch 160/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0977 - val_loss: 0.0046 - val_mean_absolute_error: 0.0780
# Epoch 161/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0951 - val_loss: 0.0076 - val_mean_absolute_error: 0.1063
# Epoch 162/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0977 - val_loss: 0.0094 - val_mean_absolute_error: 0.1192
# Epoch 163/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0965 - val_loss: 0.0054 - val_mean_absolute_error: 0.0848
# Epoch 164/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0953 - val_loss: 0.0045 - val_mean_absolute_error: 0.0764
# Epoch 165/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0948 - val_loss: 0.0051 - val_mean_absolute_error: 0.0835
# Epoch 166/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0962 - val_loss: 0.0053 - val_mean_absolute_error: 0.0844
# Epoch 167/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0948 - val_loss: 0.0081 - val_mean_absolute_error: 0.1100
# Epoch 168/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0940 - val_loss: 0.0097 - val_mean_absolute_error: 0.1216
# Epoch 169/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0936 - val_loss: 0.0092 - val_mean_absolute_error: 0.1183
# Epoch 170/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0940 - val_loss: 0.0066 - val_mean_absolute_error: 0.0989
# Epoch 171/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0993 - val_loss: 0.0042 - val_mean_absolute_error: 0.0685
# Epoch 172/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0102 - mean_absolute_error: 0.1101 - val_loss: 0.0047 - val_mean_absolute_error: 0.0801
# Epoch 173/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0974 - val_loss: 0.0068 - val_mean_absolute_error: 0.1006
# Epoch 174/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0980 - val_loss: 0.0049 - val_mean_absolute_error: 0.0800
# Epoch 175/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0092 - mean_absolute_error: 0.1023 - val_loss: 0.0059 - val_mean_absolute_error: 0.0920
# Epoch 176/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0953 - val_loss: 0.0059 - val_mean_absolute_error: 0.0921
# Epoch 177/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0923 - val_loss: 0.0075 - val_mean_absolute_error: 0.1049
# Epoch 178/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0924 - val_loss: 0.0086 - val_mean_absolute_error: 0.1141
# Epoch 179/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0924 - val_loss: 0.0057 - val_mean_absolute_error: 0.0890
# Epoch 180/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0926 - val_loss: 0.0043 - val_mean_absolute_error: 0.0765
# Epoch 181/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0969 - val_loss: 0.0042 - val_mean_absolute_error: 0.0759
# Epoch 182/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0941 - val_loss: 0.0045 - val_mean_absolute_error: 0.0748
# Epoch 183/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.1001 - val_loss: 0.0092 - val_mean_absolute_error: 0.1184
# Epoch 184/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0955 - val_loss: 0.0103 - val_mean_absolute_error: 0.1263
# Epoch 185/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0923 - val_loss: 0.0068 - val_mean_absolute_error: 0.0991
# Epoch 186/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0911 - val_loss: 0.0051 - val_mean_absolute_error: 0.0843
# Epoch 187/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0955 - val_loss: 0.0042 - val_mean_absolute_error: 0.0729
# Epoch 188/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0916 - val_loss: 0.0058 - val_mean_absolute_error: 0.0916
# Epoch 189/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0958 - val_loss: 0.0069 - val_mean_absolute_error: 0.1003
# Epoch 190/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0911 - val_loss: 0.0094 - val_mean_absolute_error: 0.1195
# Epoch 191/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0920 - val_loss: 0.0108 - val_mean_absolute_error: 0.1294
# Epoch 192/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0915 - val_loss: 0.0070 - val_mean_absolute_error: 0.1017
# Epoch 193/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0900 - val_loss: 0.0053 - val_mean_absolute_error: 0.0879
# Epoch 194/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0955 - val_loss: 0.0041 - val_mean_absolute_error: 0.0717
# Epoch 195/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0929 - val_loss: 0.0058 - val_mean_absolute_error: 0.0921
# Epoch 196/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0922 - val_loss: 0.0089 - val_mean_absolute_error: 0.1163
# Epoch 197/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0935 - val_loss: 0.0086 - val_mean_absolute_error: 0.1139
# Epoch 198/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0910 - val_loss: 0.0079 - val_mean_absolute_error: 0.1096
# Epoch 199/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0934 - val_loss: 0.0049 - val_mean_absolute_error: 0.0815
# Epoch 200/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0908 - val_loss: 0.0055 - val_mean_absolute_error: 0.0885
# Epoch 201/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0898 - val_loss: 0.0081 - val_mean_absolute_error: 0.1107
# Epoch 202/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0908 - val_loss: 0.0094 - val_mean_absolute_error: 0.1201
# Epoch 203/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0902 - val_loss: 0.0077 - val_mean_absolute_error: 0.1075
# Epoch 204/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0898 - val_loss: 0.0050 - val_mean_absolute_error: 0.0828
# Epoch 205/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0932 - val_loss: 0.0061 - val_mean_absolute_error: 0.0956
# Epoch 206/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0941 - val_loss: 0.0045 - val_mean_absolute_error: 0.0785
# Epoch 207/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0913 - val_loss: 0.0043 - val_mean_absolute_error: 0.0764
# Epoch 208/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0909 - val_loss: 0.0060 - val_mean_absolute_error: 0.0946
# Epoch 209/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0950 - val_loss: 0.0056 - val_mean_absolute_error: 0.0895
# Epoch 210/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0907 - val_loss: 0.0083 - val_mean_absolute_error: 0.1121
# Epoch 211/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0923 - val_loss: 0.0094 - val_mean_absolute_error: 0.1203
# Epoch 212/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0903 - val_loss: 0.0142 - val_mean_absolute_error: 0.1520
# Epoch 213/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0933 - val_loss: 0.0083 - val_mean_absolute_error: 0.1120
# Epoch 214/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0889 - val_loss: 0.0036 - val_mean_absolute_error: 0.0629
# Epoch 215/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0972 - val_loss: 0.0036 - val_mean_absolute_error: 0.0700
# Epoch 216/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.1045 - val_loss: 0.0039 - val_mean_absolute_error: 0.0687
# Epoch 217/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0982 - val_loss: 0.0100 - val_mean_absolute_error: 0.1245
# Epoch 218/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0912 - val_loss: 0.0170 - val_mean_absolute_error: 0.1699
# Epoch 219/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0990 - val_loss: 0.0063 - val_mean_absolute_error: 0.0943
# Epoch 220/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0999 - val_loss: 0.0057 - val_mean_absolute_error: 0.0916
# Epoch 221/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0092 - mean_absolute_error: 0.1065 - val_loss: 0.0034 - val_mean_absolute_error: 0.0620
# Epoch 222/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0936 - val_loss: 0.0046 - val_mean_absolute_error: 0.0800
# Epoch 223/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0895 - val_loss: 0.0098 - val_mean_absolute_error: 0.1235
# Epoch 224/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0917 - val_loss: 0.0068 - val_mean_absolute_error: 0.0992
# Epoch 225/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0979 - val_loss: 0.0109 - val_mean_absolute_error: 0.1317
# Epoch 226/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.1082 - val_loss: 0.0050 - val_mean_absolute_error: 0.0832
# Epoch 227/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0921 - val_loss: 0.0042 - val_mean_absolute_error: 0.0746
# Epoch 228/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0922 - val_loss: 0.0052 - val_mean_absolute_error: 0.0870
# Epoch 229/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0898 - val_loss: 0.0048 - val_mean_absolute_error: 0.0794
# Epoch 230/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.0993 - val_loss: 0.0102 - val_mean_absolute_error: 0.1269
# Epoch 231/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0956 - val_loss: 0.0093 - val_mean_absolute_error: 0.1194
# Epoch 232/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0898 - val_loss: 0.0083 - val_mean_absolute_error: 0.1121
# Epoch 233/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0911 - val_loss: 0.0055 - val_mean_absolute_error: 0.0893
# Epoch 234/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0906 - val_loss: 0.0044 - val_mean_absolute_error: 0.0778
# Epoch 235/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0883 - val_loss: 0.0057 - val_mean_absolute_error: 0.0915
# Epoch 236/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0905 - val_loss: 0.0039 - val_mean_absolute_error: 0.0703
# Epoch 237/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0905 - val_loss: 0.0051 - val_mean_absolute_error: 0.0856
# Epoch 238/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0875 - val_loss: 0.0049 - val_mean_absolute_error: 0.0835
# Epoch 239/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0874 - val_loss: 0.0038 - val_mean_absolute_error: 0.0683
# Epoch 240/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0924 - val_loss: 0.0074 - val_mean_absolute_error: 0.1055
# Epoch 241/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0921 - val_loss: 0.0084 - val_mean_absolute_error: 0.1139
# Epoch 242/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0916 - val_loss: 0.0042 - val_mean_absolute_error: 0.0733
# Epoch 243/250
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0929 - val_loss: 0.0049 - val_mean_absolute_error: 0.0836
# Epoch 244/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0942 - val_loss: 0.0048 - val_mean_absolute_error: 0.0819
# Epoch 245/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0899 - val_loss: 0.0065 - val_mean_absolute_error: 0.0977
# Epoch 246/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0880 - val_loss: 0.0116 - val_mean_absolute_error: 0.1371
# Epoch 247/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0955 - val_loss: 0.0075 - val_mean_absolute_error: 0.1055
# Epoch 248/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0884 - val_loss: 0.0062 - val_mean_absolute_error: 0.0947
# Epoch 249/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0862 - val_loss: 0.0051 - val_mean_absolute_error: 0.0853
# Epoch 250/250
# 316/316 [==============================] - 1s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0884 - val_loss: 0.0036 - val_mean_absolute_error: 0.0648

# %%
y_pred_train_keras = scaler.inverse_transform(keras_model.predict(X_train_reshape, batch_size=256))
y_pred_keras = scaler.inverse_transform(keras_model.predict(X_test_reshape, batch_size=256))

# %%
# Plot what it looks like for the training data
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_keras['Adj Close Train'] = y_pred_train_keras[:-window_size]
df_keras.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %%
# Same for the test
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_keras['Adj Close Test'] = y_pred_keras
df_keras.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Finally to see how everything performs, let's plot all of the methods together for both the training and testing data.

# %%
df_train = df.copy()
df_train.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_train = df_train.iloc[window_size:ind_split] # Past 32 days we don't know yet
# Add in all of our methods
df_train['Adj Close Train Ridge'] = y_pred_train_ridge[:-window_size]
df_train['Adj Close Train Gradient Boosting'] = y_pred_train_gb[:-window_size]
df_train['Adj Close Train LSTM'] = y_pred_train_keras[:-window_size]
# Plot the data now
df_train.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %%
df_test = df.copy()
df_test.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_test = df_test.iloc[ind_split+window_size:] # Past 32 days we don't know yet
# Add in all of our methods
df_test['Adj Close Test Ridge'] = y_pred_ridge
df_test['Adj Close Test Gradient Boosting'] = y_pred_gb
df_test['Adj Close Test LSTM'] = y_pred_keras
# Plot the data now
df_test.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# take the learned model that you have, then start with the last  N  values in your data (in my case 32), and start predicting what the next values will be. With the next values, keep using the previous  N  values for your desired forecasting. We already have our learned models above, so let's go ahead and do that.

# %%
num_days = 10 # Let's try and forecase the next 10 days or two years

# Get the last window_size (32) days
data_seed = df['Adj Close'].values[-window_size:][None]
# Get the normalized data as well for the neural network
data_seed_norm = scaler.transform(data_seed)
input_values = {"ridge": data_seed, "gb": data_seed, "keras": data_seed_norm.copy()}
values = {"ridge": [], "gb": [], "keras": []}
for i in range(num_days): # For each day...
    # Predict the next price given the previous N prices
    values["ridge"].append(ridge_model.predict(input_values["ridge"])[0])
    values["gb"].append(gb_model.predict(input_values["gb"])[0])
    values["keras"].append(keras_model.predict(input_values["keras"][...,None])[0][0])

    # Dump the oldest price and put the newest price at the end
    for v in input_values:
        val = input_values[v]
        val = np.insert(val, -1, values[v][-1], axis=1)
        val = np.delete(val, 0, axis=1)
        input_values[v] = val.copy()

# Convert all to NumPy arrays
for v in input_values:
    values[v] = np.array(values[v])

# Unnormalize prices from NN approach
values["keras"] = scaler.inverse_transform(values["keras"][None])[0]

# %% [markdown]
# Now let's plot the next 10 days worth of data

# %%
from datetime import timedelta, datetime
last_date = datetime.strptime(df.index[-1], '%Y-%m-%d')
df_forecast = pd.DataFrame()
df_forecast["Ridge"] = values["ridge"]
df_forecast["Gradient Boosting"] = values["gb"]
df_forecast["Keras LSTM"] = values["keras"]
df_forecast.index = pd.date_range(start=last_date, periods=num_days)
df_forecast.plot(label='TSLA', figsize=(16,8), title='Forecasted Adjusted Closing Price', grid=True)
